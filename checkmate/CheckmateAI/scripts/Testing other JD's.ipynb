# %%
import openai
import os

openai.api_key  = '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'

# %%
def completeion(prompt, model='gpt-3.5-turbo'):
    messages = [{"role": "user", "content": prompt}]
    response = openai.ChatCompletion.create(
        model = model,
        messages = messages,
        temperature = 0 #known as degree of randomness
    )
    return response.choices[0].message['content']

# %%
# jd_store_person = """The Role
# We have an exci/ng opportunity for a mo/vated person to join our stores team. Repor/ng
# to our Warehouse & Logis/cs Manager, you will primarily be based in a chilled or frozen
# environment. This is a hands on role, not for faint hearted!
# You will:
# Provide input on ini/a/ves to ensure smooth and effec/ve opera/on of stores area.
# Coordinate with transport to ensure all receiving shipments are moving in and out of stores
# as scheduled.
# Safely operate forkliKs and reach trucks, load and unload trucks.
# Be skilled in picking and packing of product within the agreed /meframe.
# Assemble and pack outgoing orders, ensuring quality and /mely dispatch.
# Assist with stock-takes and stock rota/on and to generate reports on inventory balance and
# shortages.
# Be flexible and have ability to work with the produc/on team to meet cri/cal requirements.
# Ac/vely comply with health and safety policies and procedures
# Key requirements for this role
# Experience in a pick pack environment
# OSH cer/fied is preferred – however we can support the right candidate to get this
# endorsement.
# F endorsement is preferred – however we can support the right candidate to get this
# endorsement.
# Great aYtude to Food Safety and Health and Safety and willingness to follow all related
# instruc/ons, procedures and policies
# Ability to work independently and as part of a team.
# Work with ini/a/ve.
# Ability to work in a physically demanding role.
# Excellent numeracy and literacy skills.
# Intermediate computer skills, comfortable using email and excel spreadsheets.
# Excellent communica/on skills both verbal and wri[en.
# Be hard working, reliable, with a can-do aYtude.
# About Original Foods Baking Company
# Original Foods Baking Co. are one of New Zealand’s favourite wholesale bakery’s. We have
# been perfec/ng the art of good baking for almost 30 years, and our products are
# dangerously good!
# Proudly New Zealand owned and operated, we make a wide range of delicious baked goods
# at our Wigram based purpose-built produc/on facility and corporate headquarters, including
# cakes, brownies, muffins, slices and more, sold under the Original Foods Baking Co., Goofy
# and Bite Me brands.
# Our products can be found in leading supermarkets, quality cafes and catering companies,
# restaurants, and tourism businesses across New Zealand, Australia and the Pacific Islands.
# Our produc/on facility operates 24 hours a day, 6 days a week. With innova/ve
# manufacturing technology and experienced and highly trained staff, we are an industry
# leader."""

# %%
# jd_nurse = """Registered Nurse - Vickery Court (Invercargill)
# Mō mātou | About us:
# Presbyterian Support Southland’s (PSS) vision is a community where all people can make the
# most of their strengths and feel included, valued and safe.
# To make this vision a reality, we assist and encourage people facing life’s challenges. PSS is a
# Charitable Trust and Southland’s largest social service and aged care provider. Our two
# service arms, Family Works and Enliven, provide a range of services in response to the
# changing needs of individuals and family/whānau in the wider community of Southland.
# We work to enable a posiLve and lasLng change for everyone in our community and offer
# support services to people regardless of their beliefs, ethnicity or background.
# Mō te tūnga | About the role:
# We are looking for two Registered Nurses to join the team at Vickery Court to ensure the
# care and clinical needs of our residents are met. Vickery Court is an 88-bed care home
# facility located on North Road providing residenLal and hospital level care for our residents.
# One of the roles will be predominately night shiUs and a minimum of thirty two (32) hours
# per fortnight and the second role will need to be able to cover all shiUs as rostered and will
# be a minimum of forty eight (48) hours per fortnight.
# Our morning shiU is 6.45am to 3.15pm, aUernoon shiU 2.45pm to 11.15pm and night shiU
# from 11.00pm to 7.00am.
# To be considered for these posiLons you will need to hold a current Registered Nurse Annual
# PracLcing CerLficate from the Nursing Council of New Zealand.
# Ngā pūkenga | What you will need to be successful:
# A current New Zealand Annual PracLcing CerLficate
# Ability to work well as part of a team
# Excellent communicaLon skills
# Computer literacy
# Flexibility to work rostered shiUs
# Ngā kawenga | Key ResponsibiliLes:
# The key responsibiliLes of a Registered Nurse at PSS includes:
# working alongside dedicated and experienced RNs, ENs and Health Care Assistants
# planning, implemenLng, evaluaLng ‘resident focused’ care for residents
# providing a safe and comfortable environment for all residents
# complying with all legislaLve and clinical best pracLce guidelines, ensuring accurate
# documentaLon at all stages
# Me pēhea te tuku tono | How to apply:
# If you are a team player and commifed to responding to the care and clinical needs of our
# residents please forward your cover lefer and Curriculum Vitae to jobs@pss.org.nz.
# Please note to be considered for this role you will need to be in New Zealand and have a
# current work visa.
# Pre-employment checks may include criminal history check, drug and alcohol tesLng and a
# medical assessment."""

# %%
prompt = f"""
Your task is to help a hiring HR team analyze the domain of job from the job description provided and then 
based on the domain create a list for refrence check questions that must be asked to the person referring the candidate
for the interview based on the domain of the job you analyzed and job description provided.

Write a list of refrence check questions based on the information 
provided in the job description delimited by 
triple backticks.

The list of questions is intended to check how good the reffered candidate is for the interview, 
so questions should be technically interrogative in nature and focus on
creating most revlevent question as per the job description and the domain analyzed.

The output should in json format.

job description: ```{jd_sales}```
"""
response = completeion(prompt)
print(response)
# Out:
# {
#   "questions": [
#     "Can you provide an overview of the candidate's experience in sales development roles?",
#     "Has the candidate worked in the industrial vertical in freight forwarding or supply chain management roles?",
#     "How well does the candidate manage priorities and handle pressure?",
#     "Has the candidate demonstrated excellence in customer lead generation experience?",
#     "Has the candidate successfully developed relationships in new verticals in the freight forwarding or related market?",
#     "What is the candidate's experience in developing customer relationships with a high retention rate?",
#     "Can you comment on the candidate's consultative sales and relationship management skills?",
#     "Has the candidate been double vaccinated against COVID-19?",
#     "How does the candidate value and respect different perspectives and experiences in the workplace?",
# ...

# %%
# jd_financial_controller = """Urgently looking for an experienced financial controller to be part of the marine industry
# based at North Shore Auckland.
# Your company:
# Our client started their journey way back in 1945 right here in New Zealand, and are now
# branched out across the globe and are a worldwide market leader in navigaIon equipment
# and part of the marine industry.
# Purpose of this Role:
# This role is responsible for the strategic direcIon of all financial and accounIng
# requirements for the business
# including detailed reporIng to the Managing Director on both past performance and future
# business acIvity and
# investments, as part of both the strategic and business planning cycles. The role also has
# responsibility for the
# Company’s Finance & and HR.
# Job responsibiliIes
# Undertake financial analysis of the Company’s actual performance versus business plans
# idenIfy trends and projecIons to support decision making
# Undertake analysis of inventory / stock levels to manage supply versus investment
# Undertake analysis of capital requirements /funding
# Conduct reviews and evaluaIons for costreducIon opportuniIes
# ProacIvely manage all expense areas to minimize overhead costs while maintaining an
# effecIve operaIng environment
# What you'll need to succeed
# A champion in planning and implemenIng
# Excellent analyIcal skills
# Be a ble to plan and forecast monthly cash flow
# prepare annual budgets
# be able to prepare and present reports to the compnay board
# be able to liaise with company accountants
# ensure Imely processing of finanacial
# Strong work ethic and ambiIon to grow with the Company
# Must be an effecIve and clear communicator both verbal and wri^en
# You must be a resident /ciIzen of New Zealand or Australia and currently living in New
# Zealand in iorder to apply for this role
# Have your own transport
# Be able to provide 2 professional references
# What you'll get in return
# CompeIIve salary
# ReporIng directly to the Managing Director of the company
# Manage and work with an efficient team
# Provision to grow within the business
# Be a part of this incredible technology driven marine industry
# Regular team lunces and dinners on the company boat"""

# %%
# prompt2 = f"""
# Your task is to help a hiring HR team create a 
# list for refrence check questions that must be asked 
# at the time of interview based on a job description provided.

# Write a list of refrence check questions based on the information 
# provided in the job description delimited by 
# triple backticks.

# The list of questions is intended for interview, 
# so should be technical in nature and focus on
# creating most revlevent question as per the job description.

# job description: ```{jd_financial_controller}```
# """
# response2 = completeion(prompt2)
# print(response2)

# %%
jd_sales = """Head of Sales - Logis/cs
An exci(ng opportunity for a Head of Sales to join our growing Logis(cs team!
This role is responsible for building and maintaining a specific sales pipeline, regularly
interfacing with exis(ng and new customers and focus on expanding the DP World share of
wallet with the end customer. The Head of Sales will secure, retain, and maintain customers
including account management programs with the aim to scale the logis(cs business as well
as leveraging exis(ng networks within the related sector to drive con(nual growth.
This role will work closely with DP World business divisions and stakeholders to grow
iden(fy, build, lead and close major business opportuni(es that posi(on DP World as a
leader with the customer base.The key roles and responsibili(es of this role include but are
not limited to:
Sales and Customer Solu(ons:
Lead genera(ons to build and support current and future ver(cal specific pipeline
Regular interface with prospec(ve and current customers
Develop and build sales pipeline short, medium and long term opportunity’s that fit the
business strategy
Successfully close out customers opportuni(es which provide a profitable return to the
business and align with the DP World Sales Strategy
Establish, maintain and improve key account management prac(ces to ensure reten(on and
improvement to customer base
Work closely with commercial, subject maLer experts, key accounts customer service and
opera(ons to secure the best outcome for the customer
Pipeline Management:
Deliver all Customer KPI’s in accordance with the Sales Strategy/plan
Accountable to grow and op(mise profitable commercial revenue streams
Account Management:
Accountable for the ongoing management of allocated customer base
Accountable for growing customer base
Accountable for offering addi(onal services to exis(ng customers
About you
The successful candidate will possess the following:
7+ years’ experience in sales development role par(cularly focused on the related sector
Experience in the industrial ver(cal in freight forwarding and or supply chain management
roles
Able to manage priori(es, be well organised, methodical and deal well under pressure
Excel in customer lead genera(on experience
Experience in driving and developing rela(onships in new ver(cals in the freight forwarding
or related market
Experience in developing customer rela(onships with a high reten(on rate
Excellent consulta(ve sales and rela(onship management
As we provide an essen(al service to the Australian and New Zealand economy, we require
candidates to be able to demonstrate that they are double vaccinated against COVID19.
Suppor(ng equality
At DP World, we value and respect the different perspec(ves and experiences our people
bring to work each day. We aim to increase the diversity of our workforce – leading to a
range of different thinking, perspec(ves and ideas that create the innova(on we need to
drive beLer business results. We aim to have a work environment where everyone feels
included and everyone can realise their full poten(al.
About DP World Logis(cs
DP World are the leading global provider of smart logis(cs. Our range of services covers the
integrated supply chain – from mari(me and inland terminals to marine services and
industrial parks and technology-driven customer solu(ons. We deliver through a global
network of 300 business units in 75 countries and over 103,000 people.
In Australia we operate an integrated supply chain including container terminals and logis(cs
parks employing over 1800 people across loca(ons na(onally including Brisbane, Sydney,
Melbourne and Fremantle.
We enable the flow of global trade, every day across our business and our people are
integral to our customer promise."""

# %%
# prompt3 = f"""
# Your task is to help a hiring HR team create a 
# list for refrence check questions that must be asked 
# at the time of interview based on a job description provided.

# Write a list of refrence check questions based on the information 
# provided in the job description delimited by 
# triple backticks.

# The list of questions is intended for interview, 
# so should be technical in nature and focus on
# creating most revlevent question as per the job description.

# job description: ```{jd_sales}```
# """
# response3 = completeion(prompt3)
# print(response3)

# %%
# jd_nurse = """Registered Nurse - Vickery Court (Invercargill)
# Mō mātou | About us:
# Presbyterian Support Southland’s (PSS) vision is a community where all people can make the
# most of their strengths and feel included, valued and safe.
# To make this vision a reality, we assist and encourage people facing life’s challenges. PSS is a
# Charitable Trust and Southland’s largest social service and aged care provider. Our two
# service arms, Family Works and Enliven, provide a range of services in response to the
# changing needs of individuals and family/whānau in the wider community of Southland.
# We work to enable a posiLve and lasLng change for everyone in our community and offer
# support services to people regardless of their beliefs, ethnicity or background.
# Mō te tūnga | About the role:
# We are looking for two Registered Nurses to join the team at Vickery Court to ensure the
# care and clinical needs of our residents are met. Vickery Court is an 88-bed care home
# facility located on North Road providing residenLal and hospital level care for our residents.
# One of the roles will be predominately night shiUs and a minimum of thirty two (32) hours
# per fortnight and the second role will need to be able to cover all shiUs as rostered and will
# be a minimum of forty eight (48) hours per fortnight.
# Our morning shiU is 6.45am to 3.15pm, aUernoon shiU 2.45pm to 11.15pm and night shiU
# from 11.00pm to 7.00am.
# To be considered for these posiLons you will need to hold a current Registered Nurse Annual
# PracLcing CerLficate from the Nursing Council of New Zealand.
# Ngā pūkenga | What you will need to be successful:
# A current New Zealand Annual PracLcing CerLficate
# Ability to work well as part of a team
# Excellent communicaLon skills
# Computer literacy
# Flexibility to work rostered shiUs
# Ngā kawenga | Key ResponsibiliLes:
# The key responsibiliLes of a Registered Nurse at PSS includes:
# working alongside dedicated and experienced RNs, ENs and Health Care Assistants
# planning, implemenLng, evaluaLng ‘resident focused’ care for residents
# providing a safe and comfortable environment for all residents
# complying with all legislaLve and clinical best pracLce guidelines, ensuring accurate
# documentaLon at all stages
# Me pēhea te tuku tono | How to apply:
# If you are a team player and commifed to responding to the care and clinical needs of our
# residents please forward your cover lefer and Curriculum Vitae to jobs@pss.org.nz.
# Please note to be considered for this role you will need to be in New Zealand and have a
# current work visa.
# Pre-employment checks may include criminal history check, drug and alcohol tesLng and a
# medical assessment."""

# %%
# prompt4 = f"""
# Your task is to help a hiring HR team create a 
# list for refrence check questions that must be asked 
# at the time of interview based on a job description provided.

# Write a list of refrence check questions based on the information 
# provided in the job description delimited by 
# triple backticks.

# The list of questions is intended for interview, 
# so should be technical in nature and focus on
# creating most revlevent question as per the job description.

# job description: ```{jd_nurse}```
# """
# response4 = completeion(prompt4)
# print(response4)
